# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

files = ["C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-appliances-3987.csv", 
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-automotive-4110.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-baby_and_maternity-4433.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-bags_and_luggage-4299.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-beauty_and_health-4267.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-curve-2849.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-electronics-4395.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-home_and_kitchen-3719.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-home_textile-3883.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-jewelry_and_accessories-3548.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-pet_supplies-4083.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-kids-4314.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-mens_clothes-1891.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-office_and_school_supplies-4233.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-shoes-4381.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-sports_and_outdoors-3853.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-swimwear-3761.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-tools_and_home_improvement-3903.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-toys_and_games-3577.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-underwear_and_sleepwear-4019.csv",
        "C:\\Users\\USER\\Desktop\\Data\\Datasets\\archive\\us-shein-womens_clothing-4620.csv"]

dataframes = []
for file in files:
    df = pd.read_csv(file)
    dataframes.append(df)
dataframes[0]
# Out:
#                                  goods-title-link--jump  \
# 0     1pc Rechargeable Deep Tissue Muscle Handheld M...
# 1                         1pc Portable Hanging Neck Fan
# 2     1pc Pink Colored Curved Eyelash Curler False E...
# 3     1 Mini Portable Handheld Fan With 2 Aa Batteri...
# 4     Wit Water Flosser,Portable Oral Irrigator With...
# ...                                                 ...
# 3981                                                NaN
# 3982                                                NaN
# 3983                                                NaN
# 3984                                                NaN
# 3985                                                NaN
#
#                             goods-title-link--jump href       rank-title  \
# 0     https://us.shein.com/1pc-Rechargeable-Deep-Tis...  #1 Best Sellers
# 1     https://us.shein.com/1pc-Portable-Hanging-Neck...  #4 Best Sellers
# ...

# %%
dataframes[20]
# Out:
#                            product-locatelabels-img src  color-count  \
# 0     https://img.ltwebstatic.com/images3_pi/2024/02...          6.0
# 1                                                   NaN          4.0
# 2                                                   NaN          7.0
# 3     https://img.shein.com/images3/2024/04/30/0e/17...          9.0
# 4     https://img.ltwebstatic.com/images3_pi/2024/02...          NaN
# ...                                                 ...          ...
# 4614                                                NaN          NaN
# 4615                                                NaN          NaN
# 4616                                                NaN          5.0
# 4617                                                NaN          6.0
# 4618  https://img.ltwebstatic.com/images3_pi/2022/11...          NaN
#
#                                        goods-title-link       rank-title  \
# ...

# %%
#checking the columns of the daraframes
for i,df in enumerate(dataframes):
    print(f"df{i+1} columns: {df.columns}")
# Out:
# df1 columns: Index(['goods-title-link--jump', 'goods-title-link--jump href', 'rank-title',
#        'rank-sub', 'price', 'discount', 'selling_proposition',
#        'goods-title-link'],
#       dtype='object')
# df2 columns: Index(['goods-title-link--jump', 'goods-title-link--jump href', 'price',
#        'discount', 'selling_proposition', 'goods-title-link'],
#       dtype='object')
# df3 columns: Index(['goods-title-link--jump', 'goods-title-link--jump href',
#        'selling_proposition', 'price', 'discount', 'color-count',
#        'goods-title-link'],
#       dtype='object')
# df4 columns: Index(['color-count', 'goods-title-link--jump', 'goods-title-link--jump href',
#        'selling_proposition', 'price', 'discount', 'rank-title', 'rank-sub',
#        'goods-title-link'],
#       dtype='object')
# df5 columns: Index(['goods-title-link--jump', 'goods-title-link--jump href',
#        'selling_proposition', 'price', 'discount', 'color-count', 'rank-title',
# ...

# %%
#renaming columns
for df in dataframes:
        df.rename(columns={"goods-title-link--jump":"product title","rank-title":"rank",
                                "rank-sub":"subcategory",
                                "selling_proposition":"selling proposition",
                          "color-count": "color count"}, inplace=True)

# %%
dataframes[0]
# Out:
#                                           product title  \
# 0     1pc Rechargeable Deep Tissue Muscle Handheld M...
# 1                         1pc Portable Hanging Neck Fan
# 2     1pc Pink Colored Curved Eyelash Curler False E...
# 3     1 Mini Portable Handheld Fan With 2 Aa Batteri...
# 4     Wit Water Flosser,Portable Oral Irrigator With...
# ...                                                 ...
# 3981                                                NaN
# 3982                                                NaN
# 3983                                                NaN
# 3984                                                NaN
# 3985                                                NaN
#
#                             goods-title-link--jump href             rank  \
# 0     https://us.shein.com/1pc-Rechargeable-Deep-Tis...  #1 Best Sellers
# 1     https://us.shein.com/1pc-Portable-Hanging-Neck...  #4 Best Sellers
# ...

# %%
dataframes[20]
# Out:
#                            product-locatelabels-img src  color count  \
# 0     https://img.ltwebstatic.com/images3_pi/2024/02...          6.0
# 1                                                   NaN          4.0
# 2                                                   NaN          7.0
# 3     https://img.shein.com/images3/2024/04/30/0e/17...          9.0
# 4     https://img.ltwebstatic.com/images3_pi/2024/02...          NaN
# ...                                                 ...          ...
# 4614                                                NaN          NaN
# 4615                                                NaN          NaN
# 4616                                                NaN          5.0
# 4617                                                NaN          6.0
# 4618  https://img.ltwebstatic.com/images3_pi/2022/11...          NaN
#
#                                        goods-title-link             rank  \
# ...

# %%
#handling displaced columns
for df in dataframes:
    if 'product title' in df.columns and 'goods-title-link' in df.columns:
        df['product title'].fillna(df['goods-title-link'], inplace=True)
        df.drop('goods-title-link', axis=1, inplace=True)
    elif 'goods-title-link' in df.columns and 'product title' not in df.columns:
        df.rename(columns={"goods-title-link":"product title"}, inplace=True)

# %%
dataframes[0]
# Out:
#                                           product title  \
# 0     1pc Rechargeable Deep Tissue Muscle Handheld M...
# 1                         1pc Portable Hanging Neck Fan
# 2     1pc Pink Colored Curved Eyelash Curler False E...
# 3     1 Mini Portable Handheld Fan With 2 Aa Batteri...
# 4     Wit Water Flosser,Portable Oral Irrigator With...
# ...                                                 ...
# 3981           Unbeatablesale 142Mhz .25 Wave Kulduckie
# 3982  Unbeatablesale 440-460Mhz Load And Tip Only -B...
# 3983  TaoTronics Air Fryer, 1700W 14.8 QT, 9 In 1 Ai...
# 3984  Air Fryer 5.3 Quart, Digital Oilless Frying Co...
# 3985  Up To 350lbs Okin Motor Power Lift Recliner Ch...
#
#                             goods-title-link--jump href             rank  \
# 0     https://us.shein.com/1pc-Rechargeable-Deep-Tis...  #1 Best Sellers
# 1     https://us.shein.com/1pc-Portable-Hanging-Neck...  #4 Best Sellers
# ...

# %%
dataframes[15]
# Out:
#       color count                            blackfridaybelts-bg src  \
# 0             5.0  https://img.ltwebstatic.com/images3_ccc/2023/1...
# 1             NaN                                                NaN
# 2             8.0                                                NaN
# 3            13.0  https://img.ltwebstatic.com/images3_ccc/2023/1...
# 4             NaN  https://img.ltwebstatic.com/images3_ccc/2023/1...
# ...           ...                                                ...
# 3847          NaN                                                NaN
# 3848          NaN                                                NaN
# 3849          NaN                                                NaN
# 3850          NaN  https://img.ltwebstatic.com/images3_ccc/2023/1...
# 3851          NaN                                                NaN
#
#      blackfridaybelts-content  \
# 0                  Save $5.24
# 1                         NaN
# 2                         NaN
# ...

# %%
#removing irrelevant columns
to_drop = ['product-locatelabels-img src','blackfridaybelts-bg src', 
           'blackfridaybelts-content','goods-title-link--jump href']
for df in dataframes:
    for title in to_drop:
        if title in df.columns:
            df.drop(title, axis=1, inplace=True)

# %%
#rechecking columns
for i,df in enumerate(dataframes):
    print("df{} columns: {}".format(i+1,df.columns))
# Out:
# df1 columns: Index(['product title', 'rank', 'subcategory', 'price', 'discount',
#        'selling proposition'],
#       dtype='object')
# df2 columns: Index(['product title', 'price', 'discount', 'selling proposition'], dtype='object')
# df3 columns: Index(['product title', 'selling proposition', 'price', 'discount',
#        'color count'],
#       dtype='object')
# df4 columns: Index(['color count', 'product title', 'selling proposition', 'price',
#        'discount', 'rank', 'subcategory'],
#       dtype='object')
# df5 columns: Index(['product title', 'selling proposition', 'price', 'discount',
#        'color count', 'rank', 'subcategory'],
#       dtype='object')
# df6 columns: Index(['color count', 'product title', 'rank', 'subcategory', 'price',
#        'discount', 'selling proposition'],
#       dtype='object')
# df7 columns: Index(['product title', 'rank', 'subcategory', 'price', 'discount',
#        'selling proposition', 'color count'],
#       dtype='object')
# ...

# %%
#checking data info
for i,df in enumerate(dataframes):
    print(f"df{i+1}:")
    print(df.info())
    print()
# Out:
# df1:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3986 entries, 0 to 3985
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product title        3986 non-null   object
#  1   rank                 559 non-null    object
#  2   subcategory          559 non-null    object
#  3   price                3986 non-null   object
#  4   discount             2459 non-null   object
#  5   selling proposition  1361 non-null   object
# dtypes: object(6)
# memory usage: 187.0+ KB
# None
#
# df2:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4109 entries, 0 to 4108
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product title        4109 non-null   object
#  1   price                4109 non-null   object
#  2   discount             1373 non-null   object
# ...

# %%
#cheking missing values
for i,df in enumerate(dataframes):
        print(f"Missing values in df{i+1}:")
        print(df.isna().sum())
        print()
# Out:
# Missing values in df1:
# product title             0
# rank                   3427
# subcategory            3427
# price                     0
# discount               1527
# selling proposition    2625
# dtype: int64
#
# Missing values in df2:
# product title             0
# price                     0
# discount               2736
# selling proposition    1235
# dtype: int64
#
# Missing values in df3:
# product title             0
# selling proposition     931
# price                     0
# discount               1633
# color count            3341
# dtype: int64
#
# Missing values in df4:
# color count            2506
# product title             0
# selling proposition     646
# price                     0
# discount                145
# rank                   3893
# subcategory            3893
# dtype: int64
#
# Missing values in df5:
# product title             0
# selling proposition    1009
# price                     0
# discount                282
# ...

# %%
#checking the no of unique values of columns in each df
for i,df in enumerate(dataframes):
        print(f"Unique values in df{i+1}:\n{df.nunique()}\n" "")
# Out:
# Unique values in df1:
# product title          3627
# rank                     10
# subcategory             124
# price                  1512
# discount                 80
# selling proposition      64
# dtype: int64
#
# Unique values in df2:
# product title          3714
# price                  1022
# discount                 77
# selling proposition      58
# dtype: int64
#
# Unique values in df3:
# product title          4302
# selling proposition      76
# price                   987
# discount                 73
# color count              14
# dtype: int64
#
# Unique values in df4:
# color count              26
# product title          4105
# selling proposition      83
# price                   776
# discount                 81
# rank                     10
# subcategory              98
# dtype: int64
#
# Unique values in df5:
# product title          4134
# selling proposition     108
# price                   730
# discount                 82
# color count              26
# ...

# %%
#trimming columns:
for column in df.columns:
    df[column].map(lambda x: x.strip() if isinstance(x,str) else x)

# %%
dataframes[0]
# Out:
#                                           product title             rank  \
# 0     1pc Rechargeable Deep Tissue Muscle Handheld M...  #1 Best Sellers
# 1                         1pc Portable Hanging Neck Fan  #4 Best Sellers
# 2     1pc Pink Colored Curved Eyelash Curler False E...              NaN
# 3     1 Mini Portable Handheld Fan With 2 Aa Batteri...              NaN
# 4     Wit Water Flosser,Portable Oral Irrigator With...  #6 Best Sellers
# ...                                                 ...              ...
# 3981           Unbeatablesale 142Mhz .25 Wave Kulduckie              NaN
# 3982  Unbeatablesale 440-460Mhz Load And Tip Only -B...              NaN
# 3983  TaoTronics Air Fryer, 1700W 14.8 QT, 9 In 1 Ai...              NaN
# 3984  Air Fryer 5.3 Quart, Digital Oilless Frying Co...              NaN
# 3985  Up To 350lbs Okin Motor Power Lift Recliner Ch...              NaN
#
#                         subcategory    price discount  selling proposition
# ...

# %%
#counting rows in each df
for i,df in enumerate(dataframes):
        print(f"df{i+1}'s rows:")
        print(df.shape[0])
        print()
print("Total rows in dataframes: {}".format(sum(df.shape[0] for df in dataframes)))
# Out:
# df1's rows:
# 3986
#
# df2's rows:
# 4109
#
# df3's rows:
# 4432
#
# df4's rows:
# 4298
#
# df5's rows:
# 4266
#
# df6's rows:
# 2848
#
# df7's rows:
# 4394
#
# df8's rows:
# 3719
#
# df9's rows:
# 3882
#
# df10's rows:
# 3547
#
# df11's rows:
# 4082
#
# df12's rows:
# 4313
#
# df13's rows:
# 1890
#
# df14's rows:
# 4232
#
# df15's rows:
# 4380
#
# df16's rows:
# 3852
#
# df17's rows:
# 3760
#
# df18's rows:
# 3902
#
# df19's rows:
# 3576
#
# df20's rows:
# 4018
#
# df21's rows:
# 4619
#
# Total rows in dataframes: 82105

# %%
#counting duplicates in df
for i,df in enumerate(dataframes):
        print(f"Duplicates in df{i+1}:")
        print(df.duplicated().sum())
        print()
print("Total duplicates across dataframes: {}".format(sum(df.duplicated().sum() for df in dataframes)))
# Out:
# Duplicates in df1:
# 210
#
# Duplicates in df2:
# 183
#
# Duplicates in df3:
# 19
#
# Duplicates in df4:
# 32
#
# Duplicates in df5:
# 12
#
# Duplicates in df6:
# 103
#
# Duplicates in df7:
# 36
#
# Duplicates in df8:
# 176
#
# Duplicates in df9:
# 190
#
# Duplicates in df10:
# 180
#
# Duplicates in df11:
# 138
#
# Duplicates in df12:
# 162
#
# Duplicates in df13:
# 86
#
# Duplicates in df14:
# 92
#
# Duplicates in df15:
# 128
#
# Duplicates in df16:
# 117
#
# Duplicates in df17:
# 245
#
# Duplicates in df18:
# 96
#
# Duplicates in df19:
# 148
#
# Duplicates in df20:
# 204
#
# Duplicates in df21:
# 358
#
# Total duplicates across dataframes: 2915

# %%
for i,df in enumerate(dataframes):
        print(f"Missing values in df{i+1}:")
        print(df.isna().sum())
        print()
# Out:
# Missing values in df1:
# product title             0
# rank                   3427
# subcategory            3427
# price                     0
# discount               1527
# selling proposition    2625
# dtype: int64
#
# Missing values in df2:
# product title             0
# price                     0
# discount               2736
# selling proposition    1235
# dtype: int64
#
# Missing values in df3:
# product title             0
# selling proposition     931
# price                     0
# discount               1633
# color count            3341
# dtype: int64
#
# Missing values in df4:
# color count            2506
# product title             0
# selling proposition     646
# price                     0
# discount                145
# rank                   3893
# subcategory            3893
# dtype: int64
#
# Missing values in df5:
# product title             0
# selling proposition    1009
# price                     0
# discount                282
# ...

# %%
dataframes[18][dataframes[18]['product title'].isnull()]
# Out:
#                rank                           subcategory  price  \
# 0   #6 Best Sellers   in Kids Drawing & Painting Supplies  $2.90
# 1               NaN                                   NaN  $2.40
# 2               NaN                                   NaN  $3.80
# 3   #2 Best Sellers  in Musical Instruments & Accessories  $1.20
# 4               NaN                                   NaN  $2.31
# 5               NaN                                   NaN  $6.20
# 6   #2 Best Sellers                         in Dice Games  $0.56
# 7               NaN                                   NaN  $4.45
# 8               NaN                                   NaN  $2.90
# 9   #3 Best Sellers            in Kids Math Manipulatives  $2.96
# 10  #1 Best Sellers                    in Gaming Top Toys  $0.90
# 11              NaN                                   NaN  $2.90
#
#     selling proposition discount product title
# 0                   NaN      NaN           NaN
# ...

# %%
dataframes[18]
# Out:
#                  rank                           subcategory   price  \
# 0     #6 Best Sellers   in Kids Drawing & Painting Supplies   $2.90
# 1                 NaN                                   NaN   $2.40
# 2                 NaN                                   NaN   $3.80
# 3     #2 Best Sellers  in Musical Instruments & Accessories   $1.20
# 4                 NaN                                   NaN   $2.31
# ...               ...                                   ...     ...
# 3571              NaN                                   NaN  $45.32
# 3572              NaN                                   NaN  $79.27
# 3573              NaN                                   NaN   $3.00
# 3574              NaN                                   NaN   $6.00
# 3575              NaN                                   NaN   $1.44
#
#       selling proposition discount  \
# 0                     NaN      NaN
# 1      600+ sold recently      NaN
# 2     1.2k+ sold recently      NaN
# ...

# %%
#merging all to a df
products = pd.concat(dataframes, ignore_index=True)
products
# Out:
#                                            product title             rank  \
# 0      1pc Rechargeable Deep Tissue Muscle Handheld M...  #1 Best Sellers
# 1                          1pc Portable Hanging Neck Fan  #4 Best Sellers
# 2      1pc Pink Colored Curved Eyelash Curler False E...              NaN
# 3      1 Mini Portable Handheld Fan With 2 Aa Batteri...              NaN
# 4      Wit Water Flosser,Portable Oral Irrigator With...  #6 Best Sellers
# ...                                                  ...              ...
# 82100  Colorful Flower Embroidered Linen Muslim Women...   #2 Best Seller
# 82101  Elegant And Stylish Patchwork Lace Cheongsam D...              NaN
# 82102                  Split Thigh Satin Tube Prom Dress              NaN
# 82103  DAZY Women's Solid Color Low Waist Ultra Short...  #10 Best Seller
# 82104  SHEIN Najma Women's Elegant Solid Color Batwin...              NaN
#
#                          subcategory   price discount  selling proposition  \
# ...

# %%
products['discount']= products['discount'].str.strip("-%")
products['price'] = products['price'].str.strip("$")
products
# Out:
#                                            product title             rank  \
# 0      1pc Rechargeable Deep Tissue Muscle Handheld M...  #1 Best Sellers
# 1                          1pc Portable Hanging Neck Fan  #4 Best Sellers
# 2      1pc Pink Colored Curved Eyelash Curler False E...              NaN
# 3      1 Mini Portable Handheld Fan With 2 Aa Batteri...              NaN
# 4      Wit Water Flosser,Portable Oral Irrigator With...  #6 Best Sellers
# ...                                                  ...              ...
# 82100  Colorful Flower Embroidered Linen Muslim Women...   #2 Best Seller
# 82101  Elegant And Stylish Patchwork Lace Cheongsam D...              NaN
# 82102                  Split Thigh Satin Tube Prom Dress              NaN
# 82103  DAZY Women's Solid Color Low Waist Ultra Short...  #10 Best Seller
# 82104  SHEIN Najma Women's Elegant Solid Color Batwin...              NaN
#
#                          subcategory  price discount  selling proposition  \
# ...

# %%
products.rename(columns={"discount":"discount (%)"}, inplace=True)

# %%
#fixing missing values
products['rank'].fillna('No Rank', inplace=True)
products['subcategory'].fillna('No subcategory',inplace=True)
products['discount (%)'].fillna(0, inplace=True)
products['selling proposition'].fillna('Not Specified', inplace=True)
products['color count'].fillna(1, inplace=True)
products
# Out:
#                                            product title             rank  \
# 0      1pc Rechargeable Deep Tissue Muscle Handheld M...  #1 Best Sellers
# 1                          1pc Portable Hanging Neck Fan  #4 Best Sellers
# 2      1pc Pink Colored Curved Eyelash Curler False E...          No Rank
# 3      1 Mini Portable Handheld Fan With 2 Aa Batteri...          No Rank
# 4      Wit Water Flosser,Portable Oral Irrigator With...  #6 Best Sellers
# ...                                                  ...              ...
# 82100  Colorful Flower Embroidered Linen Muslim Women...   #2 Best Seller
# 82101  Elegant And Stylish Patchwork Lace Cheongsam D...          No Rank
# 82102                  Split Thigh Satin Tube Prom Dress          No Rank
# 82103  DAZY Women's Solid Color Low Waist Ultra Short...  #10 Best Seller
# 82104  SHEIN Najma Women's Elegant Solid Color Batwin...          No Rank
#
#                          subcategory  price discount (%)  selling proposition  \
# ...

# %%
products.isna().sum()
# Out:
# product title          14
# rank                    0
# subcategory             0
# price                   2
# discount (%)            0
# selling proposition     0
# color count             0
# dtype: int64

# %%
products.dropna(inplace=True)

# %%
print(f"Duplicates in the merged data: {products.duplicated().sum()}")
# Out:
# Duplicates in the merged data: 6600

# %%
products.drop_duplicates(inplace=True, ignore_index=True)

# %%
products
# Out:
#                                            product title             rank  \
# 0      1pc Rechargeable Deep Tissue Muscle Handheld M...  #1 Best Sellers
# 1                          1pc Portable Hanging Neck Fan  #4 Best Sellers
# 2      1pc Pink Colored Curved Eyelash Curler False E...          No Rank
# 3      1 Mini Portable Handheld Fan With 2 Aa Batteri...          No Rank
# 4      Wit Water Flosser,Portable Oral Irrigator With...  #6 Best Sellers
# ...                                                  ...              ...
# 75486  Colorful Flower Embroidered Linen Muslim Women...   #2 Best Seller
# 75487  Elegant And Stylish Patchwork Lace Cheongsam D...          No Rank
# 75488                  Split Thigh Satin Tube Prom Dress          No Rank
# 75489  DAZY Women's Solid Color Low Waist Ultra Short...  #10 Best Seller
# 75490  SHEIN Najma Women's Elegant Solid Color Batwin...          No Rank
#
#                          subcategory  price discount (%)  selling proposition  \
# ...

# %%
products.isna().sum()
# Out:
# product title          0
# rank                   0
# subcategory            0
# price                  0
# discount (%)           0
# selling proposition    0
# color count            0
# dtype: int64

# %%
#cheking datatypes
products.dtypes
# Out:
# product title           object
# rank                    object
# subcategory             object
# price                   object
# discount (%)            object
# selling proposition     object
# color count            float64
# dtype: object

# %%
#fixing datatypes
products['price']=products['price'].str.replace(",","")
products['price']=products['price'].astype('float')
products['discount']=products['discount (%)'].astype('int')

# %%
#checkinf numeric summary
products.describe().T
# Out:
#                count       mean          std   min  25%   50%    75%       max
# price        75491.0  23.431266  3235.355512  0.15  2.5  5.99  11.58  888888.0
# color count  75491.0   2.722629     3.925737  1.00  1.0  1.00   1.00      40.0
# discount     75491.0  14.699249    17.144998  0.00  0.0  8.00  23.00      92.0

# %%
products.hist(figsize=(8,5))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'color count'}>],
#        [<Axes: title={'center': 'discount'}>, <Axes: >]], dtype=object)

# %%
products[products['color count']==40]
# Out:
#                                            product title     rank  \
# 40992  1PC Personalized Red Customized Gold-Color Dog...  No Rank
#
#           subcategory  price discount (%) selling proposition  color count  \
# 40992  No subcategory    2.5            0       Not Specified         40.0
#
#        discount
# 40992         0

# %%
products[products['price']>1000]
# Out:
#                                            product title     rank  \
# 1437   VEVOR Slushy Machine, 30L Slushie Machine For ...  No Rank
# 1953   VEVOR Commercial Meatball Forming Machine, 280...  No Rank
# 2791   VEVOR Commercial Ice Cream Machine, 20-25L/H Y...  No Rank
# 3133   VEVOR 110V Frozen Yogurt Blending Machine 750W...  No Rank
# 3183   Bosch NGM5658UC 36 Inch Stainless 500 Series G...  No Rank
# 3308   BOSSCARE Full Body Zero Gravity 4D Massage Cha...  No Rank
# 3320   Artist Hand Massage Chair Full Body, SL Track ...  No Rank
# 3767   BOSSCARE 3D Full Body SL Track Massage Chair, ...  No Rank
# 3769   BOSSCARE 3D Full Body SL Track Massage Chair, ...  No Rank
# 3770   Artist Hand Full Body Massage Chair - SL Track...  No Rank
# 27227  NSX PC Gaming RYZEN 5 5600X | 16 GB RAM3600 DD...  No Rank
# 30861  This Is A Very Goods Product Name A A A A !!! ...  No Rank
# 48291                Brunello Cucinelli Bags.. Dove Grey  No Rank
# ...

# %%
products = products[products['price']!=888888]

# %%
products.describe().T
# Out:
#                count       mean        std   min  25%   50%    75%      max
# price        75490.0  11.656666  36.901736  0.15  2.5  5.99  11.58  2399.99
# color count  75490.0   2.722652   3.925758  1.00  1.0  1.00   1.00    40.00
# discount     75490.0  14.699444  17.145028  0.00  0.0  8.00  23.00    92.00

# %%
unique_subcategories = list(products['subcategory'].sort_values().unique())
print(f"Unique Subcategories are: {unique_subcategories}")
# Out:
# Unique Subcategories are: ['In Apricot Inserts & Insoles', 'In Apricot Shoe Accessories', 'In Apricot Shoe DIY Decorations', 'In Apricot Shoe Decorations', 'In Apricot Shoe Spare Parts', 'In Apricot Wide Fit Sandals', 'In Apricot Wide Fit Shoes', 'In Apricot Women Fashion Boots', 'In Apricot Women Flat Sandals', 'In Apricot Women Flats', 'In Apricot Women Flip-Flops', 'In Apricot Women Heeled Sandals', 'In Apricot Women Home Slippers', 'In Apricot Women Platforms & Wedge Sandals', 'In Apricot Women Pumps', 'In Apricot Women Sandals', 'In Apricot Women Slides', 'In Apricot Women Slippers', 'In Apricot Women Sneakers', 'In Army Green Women Casual Shoes', 'In Army Green Women Flat Sandals', 'In Army Green Women Sandals', 'In Army Green Women Shoes', 'In Baby Blue Women Casual Shoes', 'In Baby Blue Women Platforms & Wedge Sandals', 'In Baby Blue Women Pumps', 'In Baby Blue Women Sandals', 'In Baby Blue Women Sneakers', 'In Baby Pink Women Flat Sandals', 'In Baby Pink Women Heeled Sandals
# ...

# %%
products['subcategory'] = products['subcategory'].str.replace("In", "")
products['subcategory'] = products['subcategory'].str.replace("in", "")

# %%
products['subcategory'] = products['subcategory'].str.strip()
unique_subcategories = list(products['subcategory'].sort_values().unique())
print(f"Unique Subcategories are: {unique_subcategories}")
# Out:
# Unique Subcategories are: ['-ear Headphone', '4-Way Stretch Women Active Bottoms', '4-Way Stretch Women Active Sets', '4-Way Stretch Women Active Tops', '4-Way Stretch Women Activewear', '4-Way Stretch Women Sports Bras', '4-Way Stretch Women Sports Legggs', '4-Way Stretch Women Sports Sets', '4-Way Stretch Women Sports Shorts', '4-Way Stretch Women Sports timates', 'Abayas', 'Abrasives', 'Absorbs Sweat Men Activewear', 'Absorbs Sweat Men Sports Tees & Tanks', 'Absorbs Sweat Women Active Dresses', 'Absorbs Sweat Women Outdoor Tops', 'Absorbs Sweat Women Sports Bras', 'Absorbs Sweat Women Sports Legggs', 'Absorbs Sweat Women Sports Shorts', 'Absorbs Sweat Women Sports Tees & Tanks', 'Accent Furniture', 'Access Control', 'Accessories & Parts', 'Accessories DIY & Tools', 'Accessories Storage', 'Accessory Organizers', 'Acne Treatment', 'Acrylic Nail Powders & Liquids', 'Acrylic Pats', 'Adhesive Cardholders', 'Adhesive Exercise Pads', 'Adhesive Fastener Tape', 'Adhesives & Sealers', 'Adul
# ...

# %%
products['subcategory'] = products['subcategory'].str.replace("Air Fresheners", "Air Freshener Supplies")
products['subcategory'] = products['subcategory'].str.replace("Home Appliances", "Household Appliances")
products['subcategory'] = products['subcategory'].str.replace("Bath Towels", "Bathroom Towels")
products['subcategory'] = products['subcategory'].str.replace("Board Game", "Board Games")
products['subcategory'] = products['subcategory'].str.replace("Highlighter", "Highlighters")
products['subcategory'] = products['subcategory'].str.replace("Jewelry Box", "Jewelry Boxes")
products['subcategory'] = products['subcategory'].str.replace("Leisure holiday", "Leisure Vacation")
products['subcategory'] = products['subcategory'].str.replace("Make Up Bags", "Makeup Bags")
products['subcategory'] = products['subcategory'].str.replace("men usa tops", "Men USA Tops")
products['subcategory'] = products['subcategory'].str.replace("Outdoor D̩or", "Outdoor Decor")
products['subcategory'] = products['subcategory'].str.replace("Personal Care Appliance", "Personal Care Appliances")
products['subcategory'] = products['subcategory'].str.replace("Picnic Mat", "Picnic Mats")
products['subcategory'] = products['subcategory'].str.replace("Sport Bag", "Sport Bags")
products['subcategory'] = products['subcategory'].str.replace("Storage Bag", "Storage Bags")
products['subcategory'] = products['subcategory'].str.replace("Tool Bag", "Tool Bags")
products['subcategory'] = products['subcategory'].str.replace("Towel", "Towels")
products['subcategory'] = products['subcategory'].str.replace("Vollyball", "Volleyballs")
products['subcategory'] = products['subcategory'].str.replace("Wall Sticker", "Wall Stickers")
products['subcategory'] = products['subcategory'].str.replace("waterproof bag", "Waterproof Bag")
products
# Out:
#                                            product title             rank  \
# 0      1pc Rechargeable Deep Tissue Muscle Handheld M...  #1 Best Sellers
# 1                          1pc Portable Hanging Neck Fan  #4 Best Sellers
# 2      1pc Pink Colored Curved Eyelash Curler False E...          No Rank
# 3      1 Mini Portable Handheld Fan With 2 Aa Batteri...          No Rank
# 4      Wit Water Flosser,Portable Oral Irrigator With...  #6 Best Sellers
# ...                                                  ...              ...
# 75486  Colorful Flower Embroidered Linen Muslim Women...   #2 Best Seller
# 75487  Elegant And Stylish Patchwork Lace Cheongsam D...          No Rank
# 75488                  Split Thigh Satin Tube Prom Dress          No Rank
# 75489  DAZY Women's Solid Color Low Waist Ultra Short...  #10 Best Seller
# 75490  SHEIN Najma Women's Elegant Solid Color Batwin...          No Rank
#
#                     subcategory  price discount (%)  selling proposition  \
# ...

# %%
products.describe()
# Out:
#               price   color count      discount
# count  75490.000000  75490.000000  75490.000000
# mean      11.656666      2.722652     14.699444
# std       36.901736      3.925758     17.145028
# min        0.150000      1.000000      0.000000
# 25%        2.500000      1.000000      0.000000
# 50%        5.990000      1.000000      8.000000
# 75%       11.580000      1.000000     23.000000
# max     2399.990000     40.000000     92.000000

# %%
products[products['price']<0.2]
# Out:
#                                            product title             rank  \
# 16354  6 Sheets (288pcs) French Nail Art Stickers Wit...          No Rank
# 17571  Black Friday 1pack Star Design Nail Art Sequin...          No Rank
# 17930  Black Friday 10ml Shiny Sugar Nail Glitter Pow...          No Rank
# 17944  Black Friday 10ml Shiny Sugar Nail Glitter Pow...          No Rank
# 18757  Black Friday 10ml Shiny Sugar Nail Glitter Pow...          No Rank
# 19287  Black Friday 10ml Y2K Aesthetic Shiny Sugar Na...          No Rank
# 62200  Adjustable Baby Child Safety Drawer Lock - Chr...  #3 Best Sellers
#
#           subcategory  price discount (%)  selling proposition  color count  \
# 16354  No subcategory   0.15           89    40+ sold recently          1.0
# 17571  No subcategory   0.15           86  1.2k+ sold recently          1.0
# 17930  No subcategory   0.18           86   700+ sold recently          8.0
# ...

# %%
products[products.iloc[:,:4].duplicated() == True]
# Out:
#                                            product title     rank  \
# 639    1pc False Eyelashes Applicator Tool For Wear E...  No Rank
# 916    10pcs Adhesive Cable Ties, Cord Organizer For ...  No Rank
# 920    Hands-Free Fan Necklace Portable Neck Fan With...  No Rank
# 949    1PC Rechargeable 2000mAh Portable Hanging Neck...  No Rank
# 961    1 Rechargeable 1800 MAh Portable Handheld Mini...  No Rank
# ...                                                  ...      ...
# 75403   Bikinx Color Block & Simple Women's Swimsuit Set  No Rank
# 75413      Fashionable And Sexy Tie-Front Cover-Up Shirt  No Rank
# 75424  New Arrival Fashionable Sexy Plain Bikini For ...  No Rank
# 75454  SHEIN Swim Summer Beach Triangle Cup Halter So...  No Rank
# 75484      SHEIN Swim Summer Beach High Cut Bikini Panty  No Rank
#
#           subcategory  price discount (%)  selling proposition  color count  \
# 639    No subcategory   1.30            0   400+ sold recently          1.0
# ...

# %%
products = products[products.iloc[:,:4].duplicated() == False]
products
# Out:
#                                            product title             rank  \
# 0      1pc Rechargeable Deep Tissue Muscle Handheld M...  #1 Best Sellers
# 1                          1pc Portable Hanging Neck Fan  #4 Best Sellers
# 2      1pc Pink Colored Curved Eyelash Curler False E...          No Rank
# 3      1 Mini Portable Handheld Fan With 2 Aa Batteri...          No Rank
# 4      Wit Water Flosser,Portable Oral Irrigator With...  #6 Best Sellers
# ...                                                  ...              ...
# 75486  Colorful Flower Embroidered Linen Muslim Women...   #2 Best Seller
# 75487  Elegant And Stylish Patchwork Lace Cheongsam D...          No Rank
# 75488                  Split Thigh Satin Tube Prom Dress          No Rank
# 75489  DAZY Women's Solid Color Low Waist Ultra Short...  #10 Best Seller
# 75490  SHEIN Najma Women's Elegant Solid Color Batwin...          No Rank
#
#                     subcategory  price discount (%)  selling proposition  \
# ...

# %%
products = products.reset_index().drop("index", axis=1)
products
# Out:
#                                            product title             rank  \
# 0      1pc Rechargeable Deep Tissue Muscle Handheld M...  #1 Best Sellers
# 1                          1pc Portable Hanging Neck Fan  #4 Best Sellers
# 2      1pc Pink Colored Curved Eyelash Curler False E...          No Rank
# 3      1 Mini Portable Handheld Fan With 2 Aa Batteri...          No Rank
# 4      Wit Water Flosser,Portable Oral Irrigator With...  #6 Best Sellers
# ...                                                  ...              ...
# 74032  Colorful Flower Embroidered Linen Muslim Women...   #2 Best Seller
# 74033  Elegant And Stylish Patchwork Lace Cheongsam D...          No Rank
# 74034                  Split Thigh Satin Tube Prom Dress          No Rank
# 74035  DAZY Women's Solid Color Low Waist Ultra Short...  #10 Best Seller
# 74036  SHEIN Najma Women's Elegant Solid Color Batwin...          No Rank
#
#                     subcategory  price discount (%)  selling proposition  \
# ...

# %%
products.nunique()
# Out:
# product title          71479
# rank                      21
# subcategory             5051
# price                   4372
# discount (%)              91
# selling proposition      111
# color count               37
# discount                  91
# dtype: int64

# %%
products.duplicated().sum()
# Out:
# 0

# %%
products.iloc[:,:4].duplicated().sum()
# Out:
# 0

# %%
products.to_csv('allecommerce_clean.csv')

# %%
pd.read_csv('allecommerce_clean.csv')
# Out:
#        Unnamed: 0                                      product title  \
# 0               0  1pc Rechargeable Deep Tissue Muscle Handheld M...
# 1               1                      1pc Portable Hanging Neck Fan
# 2               2  1pc Pink Colored Curved Eyelash Curler False E...
# 3               3  1 Mini Portable Handheld Fan With 2 Aa Batteri...
# 4               4  Wit Water Flosser,Portable Oral Irrigator With...
# ...           ...                                                ...
# 74032       74032  Colorful Flower Embroidered Linen Muslim Women...
# 74033       74033  Elegant And Stylish Patchwork Lace Cheongsam D...
# 74034       74034                  Split Thigh Satin Tube Prom Dress
# 74035       74035  DAZY Women's Solid Color Low Waist Ultra Short...
# 74036       74036  SHEIN Najma Women's Elegant Solid Color Batwin...
#
#                   rank                subcategory  price  discount (%)  \
# ...
